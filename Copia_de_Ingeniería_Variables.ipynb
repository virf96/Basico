# %% [markdown]
# <a href="https://colab.research.google.com/github/virf96/Basico/blob/main/Copia_de_Ingenier%C3%ADa_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/My Drive/datasets/feat_ing.csv")

# %%
#Identificamos duplicados
df.duplicated().sum()
# Out:
# 0

# %%
#Renombramos la siguiente variable
df=df.rename(columns={"c_feat_59":"temperatura"})

# %%
#Transformamos la variable a fecha
df.date=pd.to_datetime(df.date, dayfirst = True)

# %%
#Veamos la frecuencia de las fechas
df["date"].diff().describe()
# Out:
# count                         2079
# mean     1 days 00:18:05.165945165
# std      0 days 00:08:27.401672296
# min                1 days 00:04:00
# 25%                1 days 00:11:00
# 50%                1 days 00:18:00
# 75%                1 days 00:25:00
# max                1 days 00:32:00
# Name: date, dtype: object

# %%
#Eliminamos la siguiente columna
df.drop(columns=["c_feat_60"],inplace=True)

# %%
#Hacemos un desface de la siguiente varibale
df["temperatura"].shift(-1)
# Out:
# 0       0.0044
# 1       0.0078
# 2       0.0117
# 3       0.0094
# 4       0.0062
#          ...
# 2075    0.0067
# 2076    0.0031
# 2077    0.0048
# 2078    0.0115
# 2079       NaN
# Name: temperatura, Length: 2080, dtype: float64

# %%
df["temperatura"]
# Out:
# 0       0.0032
# 1       0.0044
# 2       0.0078
# 3       0.0117
# 4       0.0094
#          ...
# 2075    0.0157
# 2076    0.0067
# 2077    0.0031
# 2078    0.0048
# 2079    0.0115
# Name: temperatura, Length: 2080, dtype: float64

# %%
#un desface de 2 periodos
df["temperatura"].shift(2)
# Out:
# 0          NaN
# 1          NaN
# 2       0.0032
# 3       0.0044
# 4       0.0078
#          ...
# 2075    0.0031
# 2076    0.0103
# 2077    0.0157
# 2078    0.0067
# 2079    0.0031
# Name: temperatura, Length: 2080, dtype: float64

# %% [markdown]
# ## Desfase de tu objetivo (Predecir la temperatura del día siguiente)

# %%
## Información anterior

# %%
#Desface del último periodo
df["temperatura"]=df["temperatura"].shift(-1)

# %%
df["temperatura"].tail()
# Out:
# 2075    0.0067
# 2076    0.0031
# 2077    0.0048
# 2078    0.0115
# 2079       NaN
# Name: temperatura, dtype: float64

# %%
#Desface del primeri periodo
df["c_feat_0"].diff(1)
# Out:
# 0          NaN
# 1       0.0253
# 2      -0.0191
# 3      -0.0162
# 4       0.0662
#          ...
# 2075   -0.0085
# 2076    0.0136
# 2077    0.0199
# 2078   -0.0219
# 2079   -0.0043
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
df["c_feat_0"].diff(2)
# Out:
# 0          NaN
# 1          NaN
# 2       0.0062
# 3      -0.0353
# 4       0.0500
#          ...
# 2075   -0.0148
# 2076    0.0051
# 2077    0.0335
# 2078   -0.0020
# 2079   -0.0262
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
0.0262-0.0200
# Out:
# 0.006200000000000001

# %%
df["c_feat_0"]
# Out:
# 0       0.0200
# 1       0.0453
# 2       0.0262
# 3       0.0100
# 4       0.0762
#          ...
# 2075    0.0187
# 2076    0.0323
# 2077    0.0522
# 2078    0.0303
# 2079    0.0260
# Name: c_feat_0, Length: 2080, dtype: float64

# %% [markdown]
# ## Ventanas de tiempo

# %%
#Media de una ventana de tiempo
df["c_feat_0"].rolling(3).mean()
# Out:
# 0            NaN
# 1            NaN
# 2       0.030500
# 3       0.027167
# 4       0.037467
#           ...
# 2075    0.026467
# 2076    0.026067
# 2077    0.034400
# 2078    0.038267
# 2079    0.036167
# Name: c_feat_0, Length: 2080, dtype: float64

# %% [markdown]
# ## Información del día anterior

# %%
df["c_feat_0"].shift(1)
# Out:
# 0          NaN
# 1       0.0200
# 2       0.0453
# 3       0.0262
# 4       0.0100
#          ...
# 2075    0.0272
# 2076    0.0187
# 2077    0.0323
# 2078    0.0522
# 2079    0.0303
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
df["c_feat_0"]
# Out:
# 0       0.0200
# 1       0.0453
# 2       0.0262
# 3       0.0100
# 4       0.0762
#          ...
# 2075    0.0187
# 2076    0.0323
# 2077    0.0522
# 2078    0.0303
# 2079    0.0260
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
#Porcentaje de cambio entre un periodo y otro
df["c_feat_0"].pct_change(1)
# Out:
# 0            NaN
# 1       1.265000
# 2      -0.421634
# 3      -0.618321
# 4       6.620000
#           ...
# 2075   -0.312500
# 2076    0.727273
# 2077    0.616099
# 2078   -0.419540
# 2079   -0.141914
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
#Porcentaje de cambio del último periodo al primero
df["c_feat_0"].pct_change(-1)
# Out:
# 0      -0.558499
# 1       0.729008
# 2       1.620000
# 3      -0.868766
# 4       1.664336
#           ...
# 2075   -0.421053
# 2076   -0.381226
# 2077    0.722772
# 2078    0.165385
# 2079         NaN
# Name: c_feat_0, Length: 2080, dtype: float64

# %%
(0.0453-0.0200)/0.0200
# Out:
# 1.265

# %%
(0.0200-0.0453)/0.0453
# Out:
# -0.5584988962472406

# %%
variables=(df.filter(like="c_").columns)

# %%
variables
# Out:
# Index(['c_feat_0', 'c_feat_1', 'c_feat_2', 'c_feat_3', 'c_feat_4', 'c_feat_5',
#        'c_feat_6', 'c_feat_7', 'c_feat_8', 'c_feat_9', 'c_feat_10',
#        'c_feat_11', 'c_feat_12', 'c_feat_13', 'c_feat_14', 'c_feat_15',
#        'c_feat_16', 'c_feat_17', 'c_feat_18', 'c_feat_19', 'c_feat_20',
#        'c_feat_21', 'c_feat_22', 'c_feat_23', 'c_feat_24', 'c_feat_25',
#        'c_feat_26', 'c_feat_27', 'c_feat_28', 'c_feat_29', 'c_feat_30',
#        'c_feat_31', 'c_feat_32', 'c_feat_33', 'c_feat_34', 'c_feat_35',
#        'c_feat_36', 'c_feat_37', 'c_feat_38', 'c_feat_39', 'c_feat_40',
#        'c_feat_41', 'c_feat_42', 'c_feat_43', 'c_feat_44', 'c_feat_45',
#        'c_feat_46', 'c_feat_47', 'c_feat_48', 'c_feat_49', 'c_feat_50',
#        'c_feat_51', 'c_feat_52', 'c_feat_53', 'c_feat_54', 'c_feat_55',
#        'c_feat_56', 'c_feat_57', 'c_feat_58'],
#       dtype='object')

# %%
df[f"c_feat_0_diff_1"]=df["c_feat_0"].diff(1)

# %%
df[f"c_feat_0_diff_1"]
# Out:
# 0          NaN
# 1       0.0253
# 2      -0.0191
# 3      -0.0162
# 4       0.0662
#          ...
# 2075   -0.0085
# 2076    0.0136
# 2077    0.0199
# 2078   -0.0219
# 2079   -0.0043
# Name: c_feat_0_diff_1, Length: 2080, dtype: float64

# %%
#ventanas de tiempo de dos periodos
df[f"c_feat_0_roll_mean"] = df["c_feat_0"].rolling(2).mean()
#información del día anterior
df[f"c_feat_0_shift_1"] = df["c_feat_0"].shift(1)
#porcentaje de cambio
df[f"c_feat_0_pct_1"]= df["c_feat_0"].pct_change(1)

# %%
df.head(5)
# Out:
#                  date  c_feat_0  ...  c_feat_0_shift_1  c_feat_0_pct_1
# 0 2010-12-01 00:00:00    0.0200  ...               NaN             NaN
# 1 2010-12-02 00:04:00    0.0453  ...            0.0200        1.265000
# 2 2010-12-03 00:36:00    0.0262  ...            0.0453       -0.421634
# 3 2010-12-04 00:50:00    0.0100  ...            0.0262       -0.618321
# 4 2010-12-05 01:15:00    0.0762  ...            0.0100        6.620000
#
# [5 rows x 65 columns]

# %%
for col in variables:
    for i in range(12):
        df[f"{col}_diff_{i+1}"] = df[f"{col}"].diff(i+1)
        df[f"{col}_ma_{i+1}"] = df[f"{col}"].rolling(i+1).mean()
        df[f"{col}_t-{i+1}"] = df[f"{col}"].shift(i+1)
        df[f"{col}_pct_{i+1}"] = df[f"{col}"].pct_change(i+1)

# %%
df.head(5)
# Out:
#                  date  c_feat_0  ...  c_feat_58_t-12  c_feat_58_pct_12
# 0 2010-12-01 00:00:00    0.0200  ...             NaN               NaN
# 1 2010-12-02 00:04:00    0.0453  ...             NaN               NaN
# 2 2010-12-03 00:36:00    0.0262  ...             NaN               NaN
# 3 2010-12-04 00:50:00    0.0100  ...             NaN               NaN
# 4 2010-12-05 01:15:00    0.0762  ...             NaN               NaN
#
# [5 rows x 2895 columns]

# %%
df.shape
# Out:
# (2080, 2895)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
#Definimos un polinomio de segundo grado
poly = PolynomialFeatures(2)

# %%
poly
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %%
#Será aplicado a las siguientes variable spara crear nuevas
variables
# Out:
# Index(['c_feat_0', 'c_feat_1', 'c_feat_2', 'c_feat_3', 'c_feat_4', 'c_feat_5',
#        'c_feat_6', 'c_feat_7', 'c_feat_8', 'c_feat_9', 'c_feat_10',
#        'c_feat_11', 'c_feat_12', 'c_feat_13', 'c_feat_14', 'c_feat_15',
#        'c_feat_16', 'c_feat_17', 'c_feat_18', 'c_feat_19', 'c_feat_20',
#        'c_feat_21', 'c_feat_22', 'c_feat_23', 'c_feat_24', 'c_feat_25',
#        'c_feat_26', 'c_feat_27', 'c_feat_28', 'c_feat_29', 'c_feat_30',
#        'c_feat_31', 'c_feat_32', 'c_feat_33', 'c_feat_34', 'c_feat_35',
#        'c_feat_36', 'c_feat_37', 'c_feat_38', 'c_feat_39', 'c_feat_40',
#        'c_feat_41', 'c_feat_42', 'c_feat_43', 'c_feat_44', 'c_feat_45',
#        'c_feat_46', 'c_feat_47', 'c_feat_48', 'c_feat_49', 'c_feat_50',
#        'c_feat_51', 'c_feat_52', 'c_feat_53', 'c_feat_54', 'c_feat_55',
#        'c_feat_56', 'c_feat_57', 'c_feat_58'],
#       dtype='object')

# %%
df_pol = poly.fit_transform(df[variables])

# %%
df_pol
# Out:
# array([[1.0000e+00, 2.0000e-02, 3.7100e-02, ..., 7.0560e-05, 7.5600e-05,
#         8.1000e-05],
#        [1.0000e+00, 4.5300e-02, 5.2300e-02, ..., 2.4010e-05, 2.5480e-05,
#         2.7040e-05],
#        [1.0000e+00, 2.6200e-02, 5.8200e-02, ..., 2.6896e-04, 1.5580e-04,
#         9.0250e-05],
#        ...,
#        [1.0000e+00, 5.2200e-02, 4.3700e-02, ..., 1.9044e-04, 1.0626e-04,
#         5.9290e-05],
#        [1.0000e+00, 3.0300e-02, 3.5300e-02, ..., 6.2410e-05, 2.8440e-05,
#         1.2960e-05],
#        [1.0000e+00, 2.6000e-02, 3.6300e-02, ..., 1.2960e-05, 2.1960e-05,
#         3.7210e-05]])

# %%
df_pol = pd.DataFrame(columns=poly.get_feature_names(), data=df_pol)

# %%
len(variables)
# Out:
# 59

# %%
df_pol
# Out:
#         1      x0      x1      x2  ...   x56 x58     x57^2   x57 x58     x58^2
# 0     1.0  0.0200  0.0371  0.0428  ...  0.000162  0.000071  0.000076  0.000081
# 1     1.0  0.0453  0.0523  0.0843  ...  0.000073  0.000024  0.000025  0.000027
# 2     1.0  0.0262  0.0582  0.1099  ...  0.000300  0.000269  0.000156  0.000090
# 3     1.0  0.0100  0.0171  0.0623  ...  0.000020  0.000019  0.000018  0.000016
# 4     1.0  0.0762  0.0666  0.0481  ...  0.000077  0.000023  0.000051  0.000114
# ...   ...     ...     ...     ...  ...       ...       ...       ...       ...
# 2075  1.0  0.0187  0.0346  0.0168  ...  0.000125  0.000132  0.000222  0.000372
# 2076  1.0  0.0323  0.0101  0.0298  ...  0.000021  0.000010  0.000020  0.000038
# 2077  1.0  0.0522  0.0437  0.0180  ...  0.000108  0.000190  0.000106  0.000059
# 2078  1.0  0.0303  0.0353  0.0490  ...  0.000012  0.000062  0.000028  0.000013
# 2079  1.0  0.0260  0.0363  0.0136  ...  0.000024  0.000013  0.000022  0.000037
#
# ...

# %% [markdown]
# ## Agrupación de datos

# %%
from scipy.stats import kurtosis 
from scipy.stats import skew

# %%
variables
# Out:
# Index(['c_feat_0', 'c_feat_1', 'c_feat_2', 'c_feat_3', 'c_feat_4', 'c_feat_5',
#        'c_feat_6', 'c_feat_7', 'c_feat_8', 'c_feat_9', 'c_feat_10',
#        'c_feat_11', 'c_feat_12', 'c_feat_13', 'c_feat_14', 'c_feat_15',
#        'c_feat_16', 'c_feat_17', 'c_feat_18', 'c_feat_19', 'c_feat_20',
#        'c_feat_21', 'c_feat_22', 'c_feat_23', 'c_feat_24', 'c_feat_25',
#        'c_feat_26', 'c_feat_27', 'c_feat_28', 'c_feat_29', 'c_feat_30',
#        'c_feat_31', 'c_feat_32', 'c_feat_33', 'c_feat_34', 'c_feat_35',
#        'c_feat_36', 'c_feat_37', 'c_feat_38', 'c_feat_39', 'c_feat_40',
#        'c_feat_41', 'c_feat_42', 'c_feat_43', 'c_feat_44', 'c_feat_45',
#        'c_feat_46', 'c_feat_47', 'c_feat_48', 'c_feat_49', 'c_feat_50',
#        'c_feat_51', 'c_feat_52', 'c_feat_53', 'c_feat_54', 'c_feat_55',
#        'c_feat_56', 'c_feat_57', 'c_feat_58'],
#       dtype='object')

# %%
variables=list(variables)[:50]

# %%
df=df.set_index("date")

# %%
df[:10].resample('1D').agg(lambda x:x*2)
# Out:
#             c_feat_0  c_feat_1  ...  c_feat_58_t-12  c_feat_58_pct_12
# date                            ...
# 2010-12-01    0.0400    0.0742  ...             NaN               NaN
# 2010-12-02    0.0906    0.1046  ...             NaN               NaN
# 2010-12-03    0.0524    0.1164  ...             NaN               NaN
# 2010-12-04    0.0200    0.0342  ...             NaN               NaN
# 2010-12-05    0.1524    0.1332  ...             NaN               NaN
# 2010-12-06    0.0572    0.0906  ...             NaN               NaN
# 2010-12-07    0.0634    0.1912  ...             NaN               NaN
# 2010-12-08    0.1038    0.1096  ...             NaN               NaN
# 2010-12-09    0.0446    0.0750  ...             NaN               NaN
# 2010-12-10    0.0328    0.0346  ...             NaN               NaN
#
# [10 rows x 2894 columns]

# %%
#Agregamos kurtosis de las variables
df.resample('1M').agg(lambda x:kurtosis(x))
# Out:
#             c_feat_0   c_feat_1  c_feat_2  c_feat_3  c_feat_4  c_feat_5  \
# date
# 2010-12-31  1.577279  -0.364240  0.335871  1.085080  1.123789  0.111998
# 2011-01-31 -0.597646  -0.000249 -0.329638  0.195361  1.469254  0.641095
# 2011-02-28  6.074837  14.404978  6.013429  6.171208  1.617851 -0.698531
# 2011-03-31  6.879383   8.569782  6.789442  8.724158  3.483594  2.448794
# 2011-04-30 -0.626398  -0.589480 -0.714341 -1.008751  0.358484  0.376010
# ...              ...        ...       ...       ...       ...       ...
# 2016-05-31  4.915114   5.424679  5.253140  7.895188  2.942587  4.070309
# 2016-06-30 -0.152013  -1.186992  0.087020 -0.574201 -0.402883  0.693928
# 2016-07-31  2.007774   3.335997  0.581672  0.426164  5.938600  0.788569
# 2016-08-31  0.611854   0.932582  0.091877 -0.752976 -0.743688  0.303893
# 2016-09-30 -0.412701  -0.073867 -0.637774 -1.678193 -0.463941 -0.731004
#
#             c_feat_6  c_feat_7  c_feat_8  c_feat_9  ...  c_feat_50  c_feat_51  \
# ...

# %%
#Ahora agregamos el sesgo
df.resample('1M').agg(lambda x:skew(x))
# Out:
#             c_feat_0  c_feat_1  c_feat_2  c_feat_3  c_feat_4  c_feat_5  \
# date
# 2010-12-31  1.415046  0.438703  0.956127  1.315680  1.204588  1.045290
# 2011-01-31  0.723445  0.942476  0.760333  0.811127  1.376330  1.059856
# 2011-02-28  2.113309  3.652843  2.277630  2.172100  1.231538  0.179475
# 2011-03-31  2.215656  2.696651  2.517018  2.760120  1.670859  1.358028
# 2011-04-30  0.603328  0.007689  0.386221  0.264691  0.854676  0.469238
# ...              ...       ...       ...       ...       ...       ...
# 2016-05-31  1.938851  2.292712  2.209436  2.597156  1.587158  1.872410
# 2016-06-30  0.990353  0.234543  0.944766  0.668461  0.282094  0.174617
# 2016-07-31  1.588350  1.721530  1.206870  0.867211  2.172957  0.695278
# 2016-08-31  0.699933  1.017878  0.297538  0.292479  0.049117  0.621809
# 2016-09-30  0.840348 -1.176023  0.951964  0.264718  0.933482 -0.607161
#
#             c_feat_6  c_feat_7  c_feat_8  c_feat_9  ...  c_feat_50  c_feat_51  \
# ...
