# %% [markdown]
# <a href="https://colab.research.google.com/github/virf96/Basico/blob/main/Decision_Tree_Regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
X = boston.data
y = boston.target

# %%
X
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(max_depth=3)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y_pred = model.predict(X_test)

# %%
import graphviz

# %%
from sklearn.tree import plot_tree, export_graphviz

# %%
fig = plt.figure(figsize=(25,20))
_ = plot_tree(model, feature_names=boston.feature_names, filled=True)

# %%
fig.savefig("decistion_tree_regressor.png")

# %%
dot_data = export_graphviz(model, out_file=None, 
                                feature_names=boston.feature_names,  
                                filled=True)
graph=graphviz.Source(dot_data, format="png") 
graph

# %%
graph.render("decision_tree_graphivz_regressor")
# Out:
# 'decision_tree_graphivz_regressor.png'
