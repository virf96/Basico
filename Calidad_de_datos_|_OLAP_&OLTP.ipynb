# %% [markdown]
# <a href="https://colab.research.google.com/github/virf96/Basico/blob/main/Calidad_de_datos_%7C_OLAP_%26OLTP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option("display.max_columns",200)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/My Drive/datasets/datos_mustra_1.csv",)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    edad  minutos                        monto_de_apoyo  horas  ent_regis  \
# 0  4069       27                                   NaN     16        1.0
# 1  4093        0                              31446.48      6        NaN
# 2  4092       30                              65673.63     16        1.0
# 3  4047       58  Sistema Tecnológico de Jalisco, A.C.      3        NaN
# 4  4040       50                              30254.04      6        1.0
#
#    mun_regis  ent_resid  mun_resid  ent_ocurr  mun_ocurr  \
# 0          1          1          1        NaN          1
# 1          1          1          1        NaN          1
# 2          1          1          1        NaN          1
# 3          1          1          1        NaN          1
# 4          1          1          1        NaN          1
#
#                                    sexo  ocupacion  edo_civil  lugar_ocur  \
# 0                                   NaN         11        NaN          88
# ...

# %%
#Veamos las dimensiones del data frame
df.shape
# Out:
# (655341, 26)

# %%
#Ahora las características de las variables
df.dtypes
# Out:
# edad                         int64
# minutos                      int64
# monto_de_apoyo              object
# horas                        int64
# ent_regis                  float64
# mun_regis                    int64
# ent_resid                    int64
# mun_resid                    int64
# ent_ocurr                  float64
# mun_ocurr                    int64
# sexo                        object
# ocupacion                    int64
# edo_civil                  float64
# lugar_ocur                   int64
# sitio_ocur                   int64
# nacionalid                   int64
# embarazo                     int64
# grupo                        int64
# lengua                     float64
# clave                        int64
# escolarida                   int64
# fecha_nac                   object
# fecha_ocurr                 object
# programa_fondo              object
# nombre_del_proyecto         object
# nombre_del_beneficiario     object
# dtype: object

# %%
#Identificamos is hay duplicados
df.duplicated().sum()
# Out:
# 8

# %%
#Borramos los duplicados
df.drop_duplicates(inplace=True)

# %%
#Verificamos el cambio
df.duplicated().sum()
# Out:
# 0

# %%
#Identificamos los niveles de la variable y su frecuencia dentro del df
df["edad"].value_counts()
# Out:
# 4084    14900
# 4079    14778
# 4085    14515
# 4080    14378
# 4081    14047
#         ...
# 4120        2
# 4117        2
# 4116        1
# 3098        1
# 2098        1
# Name: edad, Length: 187, dtype: int64

# %%
#Nombre de las columnas
df.columns
# Out:
# Index(['edad', 'minutos', 'monto_de_apoyo', 'horas', 'ent_regis', 'mun_regis',
#        'ent_resid', 'mun_resid', 'ent_ocurr', 'mun_ocurr', 'sexo', 'ocupacion',
#        'edo_civil', 'lugar_ocur', 'sitio_ocur', 'nacionalid', 'embarazo',
#        'grupo', 'lengua', 'clave', 'escolarida', 'fecha_nac', 'fecha_ocurr',
#        'programa_fondo', 'nombre_del_proyecto', 'nombre_del_beneficiario'],
#       dtype='object')

# %%
#Estadística descriptiva
df.describe()
# Out:
#                 edad        minutos          horas      ent_regis  \
# count  655333.000000  655333.000000  655333.000000  458941.000000
# mean     3995.239106      21.949548      12.679938      16.540176
# std       401.392086      19.509928      11.413132       8.149956
# min      1001.000000       0.000000       0.000000       1.000000
# 25%      4051.000000       0.000000       6.000000       9.000000
# 50%      4069.000000      20.000000      12.000000      15.000000
# 75%      4082.000000      35.000000      18.000000      22.000000
# max      4998.000000      99.000000      99.000000      32.000000
#
#            mun_regis      ent_resid      mun_resid  ent_ocurr      mun_ocurr  \
# count  655333.000000  655333.000000  655333.000000        0.0  655333.000000
# mean       51.515352      16.672460      55.592775        NaN      51.820590
# std        64.580768       8.121961      85.946842        NaN      73.016475
# ...

# %%
df.head()
# Out:
#    edad  minutos                        monto_de_apoyo  horas  ent_regis  \
# 0  4069       27                                   NaN     16        1.0
# 1  4093        0                              31446.48      6        NaN
# 2  4092       30                              65673.63     16        1.0
# 3  4047       58  Sistema Tecnológico de Jalisco, A.C.      3        NaN
# 4  4040       50                              30254.04      6        1.0
#
#    mun_regis  ent_resid  mun_resid  ent_ocurr  mun_ocurr  \
# 0          1          1          1        NaN          1
# 1          1          1          1        NaN          1
# 2          1          1          1        NaN          1
# 3          1          1          1        NaN          1
# 4          1          1          1        NaN          1
#
#                                    sexo  ocupacion  edo_civil  lugar_ocur  \
# 0                                   NaN         11        NaN          88
# ...

# %%
#Identificamos los niveles de la variable y la frecuencia
df["sexo"].value_counts()
# Out:
# 1                                       307728
# 2                                       249075
# 1                                        55826
# 2                                        42376
# 9                                          253
# 9                                           65
# Molina Pasquel Y Henriquez                   2
# MARICELA  LOPEZ CEPEDA\n                     2
# SFERP S.C.                                   2
# Sistema Tecnológico de Jalisco, A.C.         2
# Name: sexo, dtype: int64

# %%
#Agrupamos las variables de acuerdo a su tipo de variable
c_feats=["edad","minutos","monto_de_apoyo","horas"]
v_feats=["ent_regis","mun_regis","ent_resid","mun_resid","ent_ocurr","mun_ocurr","sexo","ocupacion","edo_civil",
        "lugar_ocur","sitio_ocur","nacionalid","embarazo","grupo","lengua","clave","escolarida"]
d_feats=["fecha_nac","fecha_ocurr"]
t_feats=["programa_fondo","nombre_del_proyecto","nombre_del_beneficiario"]

# %%
c_feats_new=["c_"+x for x in c_feats]
v_feats_new=["v_"+x for x in v_feats]
d_feats_new=["d_"+x for x in d_feats]
t_feats_new=["t_"+x for x in t_feats]

# %%
c_feats_new
# Out:
# ['c_edad', 'c_minutos', 'c_monto_de_apoyo', 'c_horas']

# %%
#Renombramos las variables
df.rename(columns=dict(zip(d_feats,d_feats_new)),inplace=True)
df.rename(columns=dict(zip(v_feats,v_feats_new)),inplace=True)
df.rename(columns=dict(zip(t_feats,t_feats_new)),inplace=True)
df.rename(columns=dict(zip(c_feats,c_feats_new)),inplace=True)

# %%
df.head()
# Out:
#    c_edad  c_minutos                      c_monto_de_apoyo  c_horas  \
# 0    4069         27                                   NaN       16
# 1    4093          0                              31446.48        6
# 2    4092         30                              65673.63       16
# 3    4047         58  Sistema Tecnológico de Jalisco, A.C.        3
# 4    4040         50                              30254.04        6
#
#    v_ent_regis  v_mun_regis  v_ent_resid  v_mun_resid  v_ent_ocurr  \
# 0          1.0            1            1            1          NaN
# 1          NaN            1            1            1          NaN
# 2          1.0            1            1            1          NaN
# 3          NaN            1            1            1          NaN
# 4          1.0            1            1            1          NaN
#
#    v_mun_ocurr                                v_sexo  v_ocupacion  \
# 0            1                                   NaN           11
# ...

# %%
df.isnull().sum()/df.shape[0]
# Out:
# c_edad                       0.000000
# c_minutos                    0.000000
# c_monto_de_apoyo             0.000003
# c_horas                      0.000000
# v_ent_regis                  0.299683
# v_mun_regis                  0.000000
# v_ent_resid                  0.000000
# v_mun_resid                  0.000000
# v_ent_ocurr                  1.000000
# v_mun_ocurr                  0.000000
# v_sexo                       0.000003
# v_ocupacion                  0.000000
# v_edo_civil                  1.000000
# v_lugar_ocur                 0.000000
# v_sitio_ocur                 0.000000
# v_nacionalid                 0.000000
# v_embarazo                   0.000000
# v_grupo                      0.000000
# v_lengua                     0.769333
# v_clave                      0.000000
# v_escolarida                 0.000000
# d_fecha_nac                  0.015836
# d_fecha_ocurr                0.000217
# t_programa_fondo             0.000000
# t_nombre_del_proyecto        0.000000
# ...

# %%
sexo=pd.read_csv("/content/drive/My Drive/datasets/desexo.csv")
ocupacion=pd.read_csv("/content/drive/My Drive/datasets/deocupa.csv")
escolaridad=pd.read_csv("/content/drive/My Drive/datasets/deesco.csv")
edad=pd.read_csv("/content/drive/My Drive/datasets/deedad.csv")

# %%
sexo.head()
# Out:
#    CVE               DESCRIP
# 0    1               Hombres
# 1    2               Mujeres
# 2    9  Sexo no especificado

# %%
#Identificamos la frecuencia de los niveles de la variable
df["v_sexo"].value_counts(1)
# Out:
# 1                                       0.469576
# 2                                       0.380075
# 1                                       0.085187
# 2                                       0.064664
# 9                                       0.000386
# 9                                       0.000099
# Molina Pasquel Y Henriquez              0.000003
# MARICELA  LOPEZ CEPEDA\n                0.000003
# SFERP S.C.                              0.000003
# Sistema Tecnológico de Jalisco, A.C.    0.000003
# Name: v_sexo, dtype: float64

# %%
#Quitamos las variables que son números
df=df[df["v_sexo"].map(lambda x:str(x).isdigit())]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0    4093          0         31446.48        6          NaN            1
# 1    4092         30         65673.63       16          1.0            1
# 2    4040         50         30254.04        6          1.0            1
# 3    4089         30         25405.81       15          1.0            1
# 4    4066         43         60336.83       22          1.0            1
#
#    v_ent_resid  v_mun_resid  v_ent_ocurr  v_mun_ocurr v_sexo  v_ocupacion  \
# 0            1            1          NaN            1      1            6
# 1            1            1          NaN            1      1            7
# 2            1            1          NaN            1      2           11
# 3            1            1          NaN            1      1           11
# 4            1            1          NaN            1      2           11
#
#    v_edo_civil  v_lugar_ocur  v_sitio_ocur  v_nacionalid  v_embarazo  v_grupo  \
# ...

# %%
sexo.head()["CVE"].index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#Cambiamos el tipo de variable de v_sexo
df["v_sexo"]=df["v_sexo"].astype(int)

# %%
df=df.merge(sexo,how="left",right_on="CVE",left_on="v_sexo")

# %%
df.head()
# Out:
#    c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0    4093          0         31446.48        6          NaN            1
# 1    4092         30         65673.63       16          1.0            1
# 2    4040         50         30254.04        6          1.0            1
# 3    4089         30         25405.81       15          1.0            1
# 4    4066         43         60336.83       22          1.0            1
#
#    v_ent_resid  v_mun_resid  v_ent_ocurr  v_mun_ocurr  v_sexo  v_ocupacion  \
# 0            1            1          NaN            1       1            6
# 1            1            1          NaN            1       1            7
# 2            1            1          NaN            1       2           11
# 3            1            1          NaN            1       1           11
# 4            1            1          NaN            1       2           11
#
# ...

# %%
#Eliminamos las siguiente columnas
df.drop(columns=["v_sexo","CVE"],inplace=True)

# %%
df.columns
# Out:
# Index(['c_edad', 'c_minutos', 'c_monto_de_apoyo', 'c_horas', 'v_ent_regis',
#        'v_mun_regis', 'v_ent_resid', 'v_mun_resid', 'v_ent_ocurr',
#        'v_mun_ocurr', 'v_ocupacion', 'v_edo_civil', 'v_lugar_ocur',
#        'v_sitio_ocur', 'v_nacionalid', 'v_embarazo', 'v_grupo', 'v_lengua',
#        'v_clave', 'v_escolarida', 'd_fecha_nac', 'd_fecha_ocurr',
#        't_programa_fondo', 't_nombre_del_proyecto',
#        't_nombre_del_beneficiario', 'DESCRIP'],
#       dtype='object')

# %%
#Renombramos la siguiente variables
df.rename(columns={"DESCRIP":"v_sexo"},inplace=True)

# %%
edad[edad["CVE"].astype(str).str.startswith("4")]
# Out:
#       CVE                          DESCRIP
# 67   4001  Un año
# 68   4002  Dos años
# 69   4003  Tres años
# 70   4004  Cuatro años
# 71   4005  Cinco años
# ..    ...                              ...
# 183  4117  Ciento diecisiete años
# 184  4118  Ciento dieciocho años
# 185  4119  Ciento diecinueve años
# 186  4120  Ciento veinte años
# 187  4998  Edad en años no especificada
#
# [121 rows x 2 columns]

# %%
#Cambiamos el tipo de variable a "str"
df["c_monto_de_apoyo"].astype(str).dtype
# Out:
# dtype('O')

# %%
#Identificamos los registros que inician con 4
df=df[df["c_edad"].map(lambda x:str(x).startswith("4"))]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df["c_edad"].dtype
# Out:
# dtype('int64')

# %%
edad
# Out:
#       CVE                          DESCRIP
# 0    1001  Una hora
# 1    1002  Dos horas
# 2    1003  Tres horas
# 3    1004  Cuatro horas
# 4    1005  Cinco horas
# ..    ...                              ...
# 183  4117  Ciento diecisiete años
# 184  4118  Ciento dieciocho años
# 185  4119  Ciento diecinueve años
# 186  4120  Ciento veinte años
# 187  4998  Edad en años no especificada
#
# [188 rows x 2 columns]

# %%
df["c_edad"].astype(str).str[-3:].astype(int)
# Out:
# 0         93
# 1         92
# 2         40
# 3         89
# 4         66
#           ..
# 629267    28
# 629268    32
# 629269    43
# 629270     3
# 629271     1
# Name: c_edad, Length: 629272, dtype: int64

# %%
df["c_edad"]=df["c_edad"].astype(str).str[-3:].astype(int)

# %%
df["c_edad"].dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#         c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0           93          0         31446.48        6          NaN            1
# 1           92         30         65673.63       16          1.0            1
# 2           40         50         30254.04        6          1.0            1
# 3           89         30         25405.81       15          1.0            1
# 4           66         43         60336.83       22          1.0            1
# ...        ...        ...              ...      ...          ...          ...
# 629267      28         99         148566.0       99          NaN           56
# 629268      32         30         491058.0        4          NaN           39
# 629269      43         20         157140.0        0         32.0           56
# 629270       3         10         149000.0       22          NaN           10
# 629271       1         40         150241.0       13         32.0           40
#
# ...

# %%
import numpy as np

# %%
#Veamos ahora los la distribución de percentiles
df["c_edad"].describe(percentiles=np.arange(0.1,1.1,.1))
# Out:
# count    629272.000000
# mean         70.412760
# std          66.978334
# min           1.000000
# 10%          36.000000
# 20%          50.000000
# 30%          58.000000
# 40%          65.000000
# 50%          70.000000
# 60%          75.000000
# 70%          80.000000
# 80%          84.000000
# 90%          89.000000
# 100%        998.000000
# max         998.000000
# Name: c_edad, dtype: float64

# %%
#Escojamos los percentiles a visualizar
df["c_edad"].describe(percentiles=[.95,.96,.97,.98,.99])
# Out:
# count    629272.000000
# mean         70.412760
# std          66.978334
# min           1.000000
# 50%          70.000000
# 95%          93.000000
# 96%          94.000000
# 97%          95.000000
# 98%          97.000000
# 99%         100.000000
# max         998.000000
# Name: c_edad, dtype: float64

# %%
df.shape
# Out:
# (629272, 26)

# %%
#Nos quedamos con solo los menores a 97
df[df["c_edad"].map(lambda x:x<97)]
# Out:
#         c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0           93          0         31446.48        6          NaN            1
# 1           92         30         65673.63       16          1.0            1
# 2           40         50         30254.04        6          1.0            1
# 3           89         30         25405.81       15          1.0            1
# 4           66         43         60336.83       22          1.0            1
# ...        ...        ...              ...      ...          ...          ...
# 629267      28         99         148566.0       99          NaN           56
# 629268      32         30         491058.0        4          NaN           39
# 629269      43         20         157140.0        0         32.0           56
# 629270       3         10         149000.0       22          NaN           10
# 629271       1         40         150241.0       13         32.0           40
#
# ...

# %%
df=df[df["c_edad"].map(lambda x:x<97)]

# %%
629272/df.shape[0]
# Out:
# 1.0224500572746993

# %%
df
# Out:
#         c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0           93          0         31446.48        6          NaN            1
# 1           92         30         65673.63       16          1.0            1
# 2           40         50         30254.04        6          1.0            1
# 3           89         30         25405.81       15          1.0            1
# 4           66         43         60336.83       22          1.0            1
# ...        ...        ...              ...      ...          ...          ...
# 629267      28         99         148566.0       99          NaN           56
# 629268      32         30         491058.0        4          NaN           39
# 629269      43         20         157140.0        0         32.0           56
# 629270       3         10         149000.0       22          NaN           10
# 629271       1         40         150241.0       13         32.0           40
#
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
#IDENTIFIQUEMOS LA FRECUECIA DE LOS NIVELES DE LA VARIABLE
df["v_ocupacion"].value_counts()
# Out:
# 11    340094
# 6      72707
# 7      39196
# 4      32395
# 2      27211
# 98     26734
# 99     24017
# 9      18429
# 8      14322
# 5       9417
# 97      5020
# 3       3448
# 1       2253
# 10       212
# Name: v_ocupacion, dtype: int64

# %%
ocupacion
# Out:
#     CVE                                            DESCRIP
# 0     1                   Funcionarios, directores y jefes
# 1     2                          Profesionistas y técnicos
# 2     3  Trabajadores auxiliares en actividades adminis...
# 3     4  Comerciantes, empleados en ventas y agentes de...
# 4     5  Trabajadores en servicios personales y vigilancia
# 5     6  Trabajadores en actividades agrícolas, ganader...
# 6     7                           Trabajadores artesanales
# 7     8  Operadores de maquinaria industrial, ensamblad...
# 8     9  Trabajadores en actividades elementales y de a...
# 9    10                                      Busca trabajo
# 10   11                                         No trabaja
# 11   97                      No aplica a menores de 5 años
# 12   98        Ocupaciones insuficientemente especificadas
# 13   99                          Ocupación no especificada

# %%
#Lo cruzamos con el catologo
df=df.merge(ocupacion,how="left",right_on="CVE",left_on="v_ocupacion")

# %%
#Eliminamos y renombramos columnas
df.drop(columns=["CVE","v_ocupacion"],inplace=True)
df.rename(columns={"DESCRIP":"v_ocupacion"},inplace=True)

# %%
df
# Out:
#         c_edad  c_minutos c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0           93          0         31446.48        6          NaN            1
# 1           92         30         65673.63       16          1.0            1
# 2           40         50         30254.04        6          1.0            1
# 3           89         30         25405.81       15          1.0            1
# 4           66         43         60336.83       22          1.0            1
# ...        ...        ...              ...      ...          ...          ...
# 615450      28         99         148566.0       99          NaN           56
# 615451      32         30         491058.0        4          NaN           39
# 615452      43         20         157140.0        0         32.0           56
# 615453       3         10         149000.0       22          NaN           10
# 615454       1         40         150241.0       13         32.0           40
#
# ...

# %%
#Unimos esolaridad co v_escolaridad
df=df.merge(escolaridad,how="left",left_on="v_escolarida",right_on="CVE")
#Eliminamos columnas
df.drop(columns=["CVE","v_escolarida"],inplace=True)
#Renombramos columnas
df.rename(columns={"DESCRIP":"v_escolarida"},inplace=True)

# %%
df["d_fecha_ocurr"].dtype
# Out:
# dtype('O')

# %%
df["d_fecha_ocurr"]=pd.to_datetime(df["d_fecha_ocurr"])

# %%
#Creamos 2 variables
df["v_fecha_ocurr_mes"]=df["d_fecha_ocurr"].map(lambda x:x.month)
df["v_fecha_ocurr_dia"]=df["d_fecha_ocurr"].map(lambda x:x.day)

# %%
list(df.filter(like="c_").columns)
# Out:
# ['c_edad', 'c_minutos', 'c_monto_de_apoyo', 'c_horas']

# %%
#Cambiamos el tipo de variable
df["c_minutos"]=df["c_minutos"].astype(int)
df["c_monto_de_apoyo"]=df["c_monto_de_apoyo"].astype(float)
df["c_horas"]=df["c_horas"].astype(int)

# %%
# Porcentaje de frecuencia de escolaridad
df["v_escolarida"].value_counts(1)
# Out:
# Primaria incompleta                       0.278862
# Sin escolaridad                           0.203048
# Primaria completa                         0.195988
# Secundaria completa                       0.098244
# Profesional                               0.068861
# Bachillerato o Preparatoria completo      0.054995
# No especificado                           0.041170
# Secundaria incompleta                     0.027714
# Bachillerato o Preparatoria incompleto    0.019527
# No aplica a menores de 3 años             0.005747
# Posgrado                                  0.004070
# Preescolar                                0.001773
# Name: v_escolarida, dtype: float64

# %%
pip install unidecode
# Out:
# ...
#      |████████████████████████████████| 245kB 2.8MB/s
# ...

# %%
from unidecode import unidecode

# %%
#Pasamos a minusculas el texto
df["v_escolarida"]=df["v_escolarida"].map(lambda x:unidecode(x.lower()))

# %%
#Frecuencia de niveles
df["v_escolarida"].value_counts(1)
# Out:
# primaria incompleta                       0.278862
# sin escolaridad                           0.203048
# primaria completa                         0.195988
# secundaria completa                       0.098244
# profesional                               0.068861
# bachillerato o preparatoria completo      0.054995
# no especificado                           0.041170
# secundaria incompleta                     0.027714
# bachillerato o preparatoria incompleto    0.019527
# no aplica a menores de 3 anos             0.005747
# posgrado                                  0.004070
# preescolar                                0.001773
# Name: v_escolarida, dtype: float64

# %%
#Diccionario para renombrar
dictio={"primaria completa":"primaria completa","primaria  completa ":"primaria completa"}

# %%
#quitamos espacios
"primaria  completa ".strip()
# Out:
# 'primaria  completa'

# %%
" primaria  completa".lstrip()
# Out:
# 'primaria  completa'

# %%
df["v_escolarida"]=df["v_escolarida"].map(lambda x:x.strip())
df["v_escolarida"]=df["v_escolarida"].map(lambda x:x.lstrip())

# %%
dictio=dict(zip(list(df["v_escolarida"].value_counts(1).index)[-2:],["otros"]*2))

# %%
lista=list(df["v_escolarida"].value_counts(1).index)

# %%
a=list(df["v_escolarida"].value_counts(1).index)[-2:]

# %%
a
# Out:
# ['posgrado', 'preescolar']

# %%
b=["otros"]*2

# %%
b
# Out:
# ['otros', 'otros']

# %%
a
# Out:
# ['posgrado', 'preescolar']

# %%
dict(zip(a,b))
# Out:
# {'posgrado': 'otros', 'preescolar': 'otros'}

# %%
type(df["v_escolarida"].value_counts(1))
# Out:
# pandas.core.series.Series

# %%
#Frecuencia de niveles
pd.DataFrame(df["v_escolarida"].value_counts(1)).reset_index()
# Out:
#                                      index  v_escolarida
# 0                      primaria incompleta      0.278862
# 1                          sin escolaridad      0.203048
# 2                        primaria completa      0.195988
# 3                      secundaria completa      0.098244
# 4                              profesional      0.068861
# 5     bachillerato o preparatoria completo      0.054995
# 6                          no especificado      0.041170
# 7                    secundaria incompleta      0.027714
# 8   bachillerato o preparatoria incompleto      0.019527
# 9            no aplica a menores de 3 anos      0.005747
# 10                                posgrado      0.004070
# 11                              preescolar      0.001773

# %%
#reemplazamos
df["v_escolarida"]=df["v_escolarida"].replace(dictio)

# %%
df["d_fecha_nac"].iloc[[0,1]]=["1","11"]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df["d_fecha_nac"].iloc[[0,1]]=["1","22"]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#    c_edad  c_minutos  c_monto_de_apoyo  c_horas  v_ent_regis  v_mun_regis  \
# 0      93          0          31446.48        6          NaN            1
# 1      92         30          65673.63       16          1.0            1
# 2      40         50          30254.04        6          1.0            1
# 3      89         30          25405.81       15          1.0            1
# 4      66         43          60336.83       22          1.0            1
#
#    v_ent_resid  v_mun_resid  v_ent_ocurr  v_mun_ocurr  v_edo_civil  \
# 0            1            1          NaN            1          NaN
# 1            1            1          NaN            1          NaN
# 2            1            1          NaN            1          NaN
# 3            1            1          NaN            1          NaN
# 4            1            1          NaN            1          NaN
#
#    v_lugar_ocur  v_sitio_ocur  v_nacionalid  v_embarazo  v_grupo  v_lengua  \
# ...

# %%
df["d_fecha_nac"]=pd.to_datetime(df["d_fecha_nac"],errors="coerce",dayfirst=True)

# %%
df["d_fecha_nac"].dropna()
# Out:
# 2        1974-12-17
# 3        1926-05-04
# 4        1949-08-25
# 5        1948-05-29
# 6        1971-08-20
#             ...
# 615450   1987-06-04
# 615451   1983-04-20
# 615452   1972-07-01
# 615453   2012-11-22
# 615454   2014-10-24
# Name: d_fecha_nac, Length: 608258, dtype: datetime64[ns]

# %%
df["d_fecha_nac"]=df["d_fecha_nac"].fillna("[2,4]")

# %%
from datetime import datetime

# %%
a="2016--12//12"

# %%
datetime.strptime(a,"%Y--%m//%d")
# Out:
# datetime.datetime(2016, 12, 12, 0, 0)

# %%
df
# Out:
#         c_edad  c_minutos  c_monto_de_apoyo  c_horas  v_ent_regis  \
# 0           93          0          31446.48        6          NaN
# 1           92         30          65673.63       16          1.0
# 2           40         50          30254.04        6          1.0
# 3           89         30          25405.81       15          1.0
# 4           66         43          60336.83       22          1.0
# ...        ...        ...               ...      ...          ...
# 615450      28         99         148566.00       99          NaN
# 615451      32         30         491058.00        4          NaN
# 615452      43         20         157140.00        0         32.0
# 615453       3         10         149000.00       22          NaN
# 615454       1         40         150241.00       13         32.0
#
#         v_mun_regis  v_ent_resid  v_mun_resid  v_ent_ocurr  v_mun_ocurr  \
# 0                 1            1            1          NaN            1
# ...

# %%
#seleccionamos 3 variables y agrupamos 2 para traer ESTADISTICOS
df[["c_edad","v_escolarida","v_sexo"]].groupby(["v_escolarida","v_sexo"]).agg(["mean","min","max","count"])
# Out:
#                                                                 c_edad      \
#                                                                   mean min
# v_escolarida                           v_sexo
# bachillerato o preparatoria completo   Hombres               52.104316  17
#                                        Mujeres               58.911955  17
# bachillerato o preparatoria incompleto Hombres               43.803466  15
#                                        Mujeres               45.781515  15
# no aplica a menores de 3 anos          Hombres                1.369318   1
#                                        Mujeres                1.336040   1
# no especificado                        Hombres               57.621041   3
#                                        Mujeres               66.928786   3
#                                        Sexo no especificado  45.272727  20
# otros                                  Hombres               55.052049   3
# ...

# %%
#Seleccionamos 3 variables, agrupamos 2 y sacamos estadisticos de 2 variables
exa=df[["c_edad","v_escolarida","v_sexo","v_clave"]].groupby(["v_escolarida","v_sexo"]).agg({"c_edad":["mean","min"],"v_clave":["max","count"]})

# %%
exa
# Out:
#                                                                 c_edad      \
#                                                                   mean min
# v_escolarida                           v_sexo
# bachillerato o preparatoria completo   Hombres               52.104316  17
#                                        Mujeres               58.911955  17
# bachillerato o preparatoria incompleto Hombres               43.803466  15
#                                        Mujeres               45.781515  15
# no aplica a menores de 3 anos          Hombres                1.369318   1
#                                        Mujeres                1.336040   1
# no especificado                        Hombres               57.621041   3
#                                        Mujeres               66.928786   3
#                                        Sexo no especificado  45.272727  20
# otros                                  Hombres               55.052049   3
# ...

# %%
exa["c_edad"]["mean"].values
# Out:
# array([52.10431568, 58.91195452, 43.80346552, 45.78151506,  1.36931818,
#         1.33603998, 57.62104143, 66.92878561, 45.27272727, 55.05204918,
#        45.3849481 , 62.77505404, 68.85881198, 70.14735325, 73.09220986,
#        94.        , 60.98524485, 62.13510683, 92.        , 50.06972997,
#        57.31276151, 46.91118887, 51.0718243 , 73.11768485, 76.46738544,
#        60.        ])

# %%
list(df.columns)
# Out:
# ['c_edad',
#  'c_minutos',
#  'c_monto_de_apoyo',
#  'c_horas',
#  'v_ent_regis',
#  'v_mun_regis',
#  'v_ent_resid',
#  'v_mun_resid',
#  'v_ent_ocurr',
#  'v_mun_ocurr',
#  'v_edo_civil',
#  'v_lugar_ocur',
#  'v_sitio_ocur',
#  'v_nacionalid',
#  'v_embarazo',
#  'v_grupo',
#  'v_lengua',
#  'v_clave',
#  'd_fecha_nac',
#  'd_fecha_ocurr',
#  't_programa_fondo',
#  't_nombre_del_proyecto',
#  't_nombre_del_beneficiario',
#  'v_sexo',
#  'v_ocupacion',
#  'v_escolarida',
#  'v_fecha_ocurr_mes',
#  'v_fecha_ocurr_dia']

# %%
pd.set_option("display.max_columns",1000)
pd.set_option("display.max_rows",1000)

# %%
for i in df.columns:
    print(i)
# Out:
# c_edad
# c_minutos
# c_monto_de_apoyo
# c_horas
# v_ent_regis
# v_mun_regis
# v_ent_resid
# v_mun_resid
# v_ent_ocurr
# v_mun_ocurr
# v_edo_civil
# v_lugar_ocur
# v_sitio_ocur
# v_nacionalid
# v_embarazo
# v_grupo
# v_lengua
# v_clave
# d_fecha_nac
# d_fecha_ocurr
# t_programa_fondo
# t_nombre_del_proyecto
# t_nombre_del_beneficiario
# v_sexo
# v_ocupacion
# v_escolarida
# v_fecha_ocurr_mes
# v_fecha_ocurr_dia
